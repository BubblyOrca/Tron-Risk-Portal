# %%
import pyfiglet
font = pyfiglet.figlet_format("LunarCrush | TRM Portal")
print(font) #clcoding.com
# Out:
#  _                            ____                _       _
# | |   _   _ _ __   __ _ _ __ / ___|_ __ _   _ ___| |__   | |
# | |  | | | | '_ \ / _` | '__| |   | '__| | | / __| '_ \  | |
# | |__| |_| | | | | (_| | |  | |___| |  | |_| \__ \ | | | | |
# |_____\__,_|_| |_|\__,_|_|   \____|_|   \__,_|___/_| |_| | |
#                                                          |_|
#  _____ ____  __  __   ____            _        _
# |_   _|  _ \|  \/  | |  _ \ ___  _ __| |_ __ _| |
#   | | | |_) | |\/| | | |_) / _ \| '__| __/ _` | |
#   | | |  _ <| |  | | |  __/ (_) | |  | || (_| | |
#   |_| |_| \_\_|  |_| |_|   \___/|_|   \__\__,_|_|

# %%
# !pip install pyfiglet==0.7.6
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 775.0/775.0 KB 55.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pyfiglet: filename=pyfiglet-0.7.6-py3-none-any.whl size=1033468 sha256=8c949a6a22f451196f3d20bf1cf5e386ec96a180ae9b5bef34f2ad5eb2a6b84c
#   Stored in directory: /root/.cache/pip/wheels/92/ad/74/283610f2ba63376c720e297ffb64640d77887ae715ba7ad03d
# Successfully built pyfiglet
# ...
# WARNING: You are using pip version 22.0.4; however, version 23.0.1 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.

# %%
# !pip install lunarcrush
# Out:
# ...
# WARNING: You are using pip version 22.0.4; however, version 23.0.1 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.

# %%
from lunarcrush import LunarCrush

lc = LunarCrush()

# %%
from lunarcrush import LunarCrushV3

lcv3 = LunarCrushV3('API KEY')

# %%
trx_insights = lcv3.get_coin_insights(coin='TRX', metrics='social_volume')

# %%
trx_insights
# Out:
# {'error': 'Invalid endpoint (2)'}

# %%
lcv3.get_coin_of_the_day()
# Out:
# {'name': 'Baby Doge Coin', 'symbol': 'BABYDOGE'}

# %%
lcv3.get_coin('TRX')
# Out:
# {'data': {'id': 12,
#   'name': 'TRON',
#   'symbol': 'TRX',
#   'price': 0.06508151799882929,
#   'price_btc': 2.829112367112e-06,
#   'market_cap': 5911904375.68,
#   'percent_change_24h': 0.158,
#   'percent_change_7d': -1.332,
#   'percent_change_30d': -2.949,
#   'volume_24h': 237385739.6,
#   'max_supply': None,
#   'circulating_supply': 90838452412.64,
#   'categories': '6',
#   'asset_id': 12,
#   'open': 0.06520977326700658,
#   'high': 0.06522232942122855,
#   'low': 0.0651425130007615,
#   'url_shares': 13,
#   'unique_url_shares': 1,
#   'reddit_comments': 1,
#   'reddit_comments_score': 2,
#   'tweets': 46,
#   'tweet_spam': 32,
#   'tweet_followers': 150661,
#   'tweet_quotes': 0,
#   'tweet_retweets': 0,
#   'tweet_replies': 0,
#   'tweet_favorites': 0,
#   'tweet_sentiment1': 1,
#   'tweet_sentiment2': 8,
#   'tweet_sentiment3': 10,
#   'tweet_sentiment4': 16,
#   'tweet_sentiment5': 11,
#   'tweet_sentiment_impact1': 7176,
#   'tweet_sentiment_impact2': 70896,
# ...

# %%
dict_TRX = lcv3.get_coin('TRX').items()
dict_TRX
# Out:
# dict_items([('data', {'id': 12, 'name': 'TRON', 'symbol': 'TRX', 'price': 0.06509667036557638, 'price_btc': 2.829112367112e-06, 'market_cap': 5913280793.22, 'percent_change_24h': 0.176, 'percent_change_7d': -1.342, 'percent_change_30d': -2.994, 'volume_24h': 237238100.78, 'max_supply': None, 'circulating_supply': 90838452412.63965, 'categories': '6', 'asset_id': 12, 'open': 0.06520977326700658, 'high': 0.06522232942122855, 'low': 0.0651425130007615, 'url_shares': 13, 'unique_url_shares': 1, 'reddit_comments': 1, 'reddit_comments_score': 2, 'tweets': 46, 'tweet_spam': 32, 'tweet_followers': 150661, 'tweet_quotes': 0, 'tweet_retweets': 0, 'tweet_replies': 0, 'tweet_favorites': 0, 'tweet_sentiment1': 1, 'tweet_sentiment2': 8, 'tweet_sentiment3': 10, 'tweet_sentiment4': 16, 'tweet_sentiment5': 11, 'tweet_sentiment_impact1': 7176, 'tweet_sentiment_impact2': 70896, 'tweet_sentiment_impact3': 35392, 'tweet_sentiment_impact4': 20189, 'tweet_sentiment_impact5': 17008, 'social_score': 150676, 
# ...

# %%
lcv3.get_market_pairs('TRX')
# Out:
# {'data': {},
#  'config': {'coin': 'TRX&limit=100&page=100',
#   'limit': 100,
#   'page': 0,
#   'generated': 1681416563}}

# %%
# Out:
# {'error': 'Invalid endpoint (2)'}

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=c920b5e4-a6cd-446a-bb4d-19c0d0e4addb' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
